# %%
import pandas as pd

# %%
file = pd.read_csv("TCGA_Nextflow/basic_workflow/work/b9/07ea14a8c0b72b4ca8fe27181e6124/maf_files/binary_numerical_merged.csv")

# %%
file
# Out:
#      Unnamed: 0          Tumor_Sample_Barcode  TTN  MUC16  TP53  LRP1B  \
# 0            27  TCGA-BR-4363-01A-01D-1158-08    1      0     1      0
# 1           187  TCGA-CG-4466-01A-01D-1158-08    1      1     1      0
# 2           223  TCGA-D7-6815-01A-11D-1882-08    0      0     1      0
# 3           197  TCGA-CG-5720-01A-11D-1600-08    0      0     0      0
# 4           247  TCGA-D7-A6F2-01A-12D-A31L-08    1      0     1      1
# ..          ...                           ...  ...    ...   ...    ...
# 96          381  TCGA-VQ-A8PH-01A-12D-A410-08    1      0     1      0
# 97           24  TCGA-BR-4357-01A-01D-1158-08    1      0     1      0
# 98          131  TCGA-BR-A4J5-01A-21D-A25D-08    1      0     0      1
# 99          170  TCGA-CG-4301-01A-01D-1158-08    0      0     0      0
# 100         319  TCGA-IN-A6RJ-01A-21D-A33T-08    1      0     0      1
#
#      ARID1A  SYNE1  CSMD3  FAT4  ...  Frame_Shift_Ins  In_Frame_Del  \
# ...
